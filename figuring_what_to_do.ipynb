# %% [markdown]
# dont know what to start with, gonna be hard

# %%
import scipy.io.wavfile
import os

# %%
file_name = "why_we_get_mad_1.wav"
file_path = os.path.join("data", file_name)

# %%
samplerate, waveform = scipy.io.wavfile.read(file_path)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(waveform)
plt.show()

# %%
len(waveform)
# Out:
# 2646000

# %%
file_name = "sine100.200.1000hz.wav"
file_path = os.path.join("data", file_name)

# %%
samplerate2, waveform2 = scipy.io.wavfile.read(file_path)

# %%
plt.plot(waveform2[0:2000])
plt.show()

# %% [markdown]
# Sound has 3 characteristics:
# * Amplitude
# * Main frequency
# * Timbre
#
# Thing is to understand, how computer can see this

# %%
from scipy.signal import spectrogram, periodogram

# %%
sample_freqs, segment_times, specgram = scipy.signal.spectrogram(waveform2)
type(specgram)
# Out:
# numpy.ndarray

# %%
len(specgram)
# Out:
# 129

# %%
type(specgram[0])
# Out:
# numpy.ndarray

# %%
plt.plot(specgram)
plt.show()

# %%
sample_freqs2, pergram = scipy.signal.periodogram(waveform2)
type(pergram)
# Out:
# numpy.ndarray

# %%
plt.plot(pergram)
plt.xlim(0, 5000)
plt.show()

# %%
sample_freqs2, pergram = scipy.signal.periodogram(waveform2,scaling="spectrum")
plt.plot(pergram)
plt.xlim(0, 5000)
plt.show()

# %%
from scipy.signal import argrelmax

# %%
argrelmax(pergram)
# Out:
# (array([     2,      5,      7, ..., 110243, 110245, 110249]),)

# %% [markdown]
# ???

# %% [markdown]
# Tea break

# %% [markdown]
# (non understandable explatation) Goal: pass through clustering algorithm array of sound characteristics and see, what categories computer gonna find

# %% [markdown]
# Characteristics to pass for now:
# * periodogram
#
# need to think how can pass amplitude

# %% [markdown]
# notes on live recording<br>
# every n seconds make a snap of m points - thats gonna be sound fragment to pass through

# %% [markdown]
# goal of the project:<br>
# make a simple live speech recognizer which is not about meaning, just detects series of letters/syllables

# %% [markdown]
# Need to decide to focus on:
# * making input data from mic live recording
# * slicing exsisting recordings from ted-talks
#
# Decided to focus on existing recs because better-looking than my own voice
